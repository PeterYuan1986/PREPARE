# %%
import os 
import glob as glob 
import numpy as np
import pandas as pd

# %%
dir_path = r"C:\Users\jinyo\Downloads\OneDrive_1_11-7-2024"

files = sorted(glob.glob(os.path.join(dir_path, "*.csv")))
files
# Out:
# ['C:\\Users\\jinyo\\Downloads\\OneDrive_1_11-7-2024\\feature_description.csv',
#  'C:\\Users\\jinyo\\Downloads\\OneDrive_1_11-7-2024\\train_features.csv',
#  'C:\\Users\\jinyo\\Downloads\\OneDrive_1_11-7-2024\\train_labels.csv']

# %%
X_df = pd.read_csv(files[1])
y_df = pd.read_csv(files[2])
description_df = pd.read_csv(files[0], encoding='unicode_escape', header=None)

# %%
description_df = description_df.drop([0])

# %%
description_df
# Out:
#                             0                                               1
# 1            age_03 / age_12                                 Binned age group
# 2        urban_03 / urban_12                                    Locality size
# 3    married_03 / married_12                                   Marital status
# 4        n_mar_03 / n_mar_12                              Number of marriages
# 5    edu_gru_03 / edu_gru_12                           Binned education level
# ..                        ...                                             ...
# 104                   a21_12          Total years lived or worked in the U.S.
# 105                   a22_12    Main job type during longest stay in the U.S.
# 106                  a33b_12                            U.S. residency status
# 107                   a34_12                                   Speaks English
# 108                   j11_12                      Floor material of residence
#
# [108 rows x 2 columns]

# %%
print(len(X_df))
print(len(y_df))
# Out:
# 3276
# 4343

# %%
X_df = X_df.sort_values(by="uid")
y_df = y_df.sort_values(by="uid")

# %%
testing_df = X_df.drop(columns=["uid"])

# %%
for column in testing_df.columns:
    if testing_df[column].dtype == "object":
        print(column)
        print(set(testing_df[column].values))
        print()
# Out:
# age_03
# {nan, '2. 60–69', '3. 70–79', '1. 50–59', '4. 80+', '0. 49 or younger'}
#
# urban_03
# {'0. <100,000', '1. 100,000+', nan}
#
# married_03
# {'2. Separated or divorced', nan, '3. Widowed', '4. Single', '1. Married or in civil union'}
#
# edu_gru_03
# {'0. No education', '1. 1–5 years', nan, '2. 6 years', '3. 7–9 years', '4. 10+ years'}
#
# n_living_child_03
# {'1. 1 or 2', nan, '4. 7+', '3. 5 or 6', '0. No children', '2. 3 or 4'}
#
# glob_hlth_03
# {'2. Very good', '3. Good', '1. Excellent', nan, '5. Poor', '4. Fair'}
#
# bmi_03
# {nan, '2. Normal weight', '1. Underweight', '3. Overweight', '4. Obese', '5. Morbidly obese'}
#
# decis_famil_03
# {'2. Approximately equal weight', '1. Respondent', nan, '3. Spouse'}
#
# employment_03
# {'2. Currently looking for work', nan, '3. Dedicated to household chores', '4. Retired, incapacitated, or does not work', '1. Currently Working'}
#
# age_12
# {nan, '2. 60–69', '3. 70–79', '1. 50–59', '4. 80+', '0. 49 or younger'}
#
# urban_12
# {'1. 100,000+', '0. <100,000', nan}
#
# married_12
# {'2. Separated or divorced', nan, '3. Widowed', '4. Single', '1. Married or in civil union'}
#
# edu_gru_12
# {'0. No education', '1. 1–5 years', nan, '2. 6 years', '3. 7–9 years', '4. 10+ years'}
#
# n_living_child_12
# {'1. 1 or 2', '4. 7+', nan, '3. 5 or 6', '0. No children', '2. 3 or 4'}
#
# glob_hlth_12
# {'2. Very good', '3. Good', '1. Excellent', nan, '5. Poor', '4. Fair'}
#
# bmi_12
# {nan, '2. Normal weight', '1. Underweight', '3. Overweight', '4. Obese', '5. Morbidly obese'}
#
# decis_famil_12
# {'2. Approximately equal weight', '1. Respondent', nan, '3. Spouse'}
#
# decis_personal_12
# {'3. None', '2. A little', '1. A lot', nan}
#
# employment_12
# {'2. Currently looking for work', nan, '3. Dedicated to household chores', '4. Retired, incapacitated, or does not work', '1. Currently Working'}
#
# satis_ideal_12
# {'3. Disagrees', '2. Neither agrees nor disagrees', nan, '1. Agrees'}
#
# satis_excel_12
# {'3. Disagrees', nan, '2. Neither agrees nor disagrees', '1. Agrees'}
#
# satis_fine_12
# {'1. Agrees', '2. Neither agrees nor disagrees', nan, '3. Disagrees'}
#
# cosas_imp_12
# {'1. Agrees', nan, '2. Neither agrees nor disagrees', '3. Disagrees'}
#
# wouldnt_change_12
# {'3. Disagrees', '2. Neither agrees nor disagrees', nan, '1. Agrees'}
#
# memory_12
# {'2. Very good', '3. Good', '1. Excellent', nan, '5. Poor', '4. Fair'}
#
# ragender
# {'1.Man', '2.Woman'}
#
# rameduc_m
# {nan, '3.Primary', '2.Some primary', '1.None', '4.More than primary'}
#
# rafeduc_m
# {nan, '3.Primary', '2.Some primary', '1.None', '4.More than primary'}
#
# sgender_03
# {'1.Man', nan, '2.Woman'}
#
# rjlocc_m_03
# {'16.Workers in the Service Industry', '2.Technicians', '3.Educators', '19.Other Workers', '12.Department Heads/Coordinators/Supervisors in Admin and Service Activities', '9.Operators of Fixed Machinery and Equipment for Ind. Production', '18.Safety and Security Personnel', '17.Domestic Workers', '1.Professionals', '15.Traveling Salespeople and Traveling Salespeople of Services', '6.Workers in Agriculture, Livestock, Forestry, and Fishing', nan, '14.Merchants and Sales Representatives', '4.Workers in Art, Shows, and Sports', '5.Officials and Directors Public, Private, and Social Sectors', '10.Asst/Laborers etc in Ind. Production, Repair, Maintenance', '11.Drivers and Asst Drivers of Mobile Machinery and Transport Vehicles', '13.Administrative Support Staff', '8.Artisans and Workers in Production, Repair, Maintenance'}
#
# rjobend_reason_03
# {nan, '4.Health reason', '5.Family reason', '1.Retired', '3.Laid off', '8.Other'}
#
# rrelgimp_03
# {'3.not important', '1.very important', nan, '2.somewhat important'}
#
# sgender_12
# {'1.Man', nan, '2.Woman'}
#
# rjlocc_m_12
# {'16.Workers in the Service Industry', '2.Technicians', '3.Educators', '12.Department Heads/Coordinators/Supervisors in Admin and Service Activities', '9.Operators of Fixed Machinery and Equipment for Ind. Production', '18.Safety and Security Personnel', '7.Bosses/Supervisors etc in Artistic, Ind. Production, Repair, Maintenance Activities', '17.Domestic Workers', '1.Professionals', '15.Traveling Salespeople and Traveling Salespeople of Services', '6.Workers in Agriculture, Livestock, Forestry, and Fishing', nan, '14.Merchants and Sales Representatives', '4.Workers in Art, Shows, and Sports', '5.Officials and Directors Public, Private, and Social Sectors', '10.Asst/Laborers etc in Ind. Production, Repair, Maintenance', '11.Drivers and Asst Drivers of Mobile Machinery and Transport Vehicles', '13.Administrative Support Staff', '8.Artisans and Workers in Production, Repair, Maintenance'}
#
# rjobend_reason_12
# {nan, '5.Family reason', '4.Health reason', '1.Retired', '3.Laid off', '8.Other'}
#
# rrelgimp_12
# {'3.not important', nan, '1.very important', '2.somewhat important'}
#
# rrfcntx_m_12
# {'2.4 or more times a week', nan, '9.Never', '6.2 or 3 times a month', '5.4 or more times a month', '1.Almost every day', '8.Almost Never, sporadic', '3.2 or 3 times a week', '7.Once a month', '4.Once a week'}
#
# rsocact_m_12
# {'2.4 or more times a week', nan, '9.Never', '6.2 or 3 times a month', '5.4 or more times a month', '1.Almost every day', '8.Almost Never, sporadic', '3.2 or 3 times a week', '7.Once a month', '4.Once a week'}
#
# rrelgwk_12
# {'1.Yes', '0.No', nan}
#
# a22_12
# {'Agriculture/ Animal breeding 01', 'Childcare or domestic work 04', nan, 'Construction/ Manufacturing/ Mining 02', 'Restaurant/ Store/ Hotel 05', 'Did not work 08', 'Other 07', 'Gardening or maintenance 03'}
#
# a33b_12
# {'Neither 3', 'Citizen 2', 'Permanent resident 1', nan}
#
# a34_12
# {'Yes 1', 'No 2', nan}
#
# j11_12
# {'Concrete 2', 'Mud 3', nan, 'Wood, mosaic, or other covering 1'}

# %%
mapping = {}

for idx in range(len(description_df)):
    description = description_df.iloc[idx,0]
    data = description_df.iloc[idx,1]
    
    description = description.strip()
    data = data.strip()
    
    if "/" in description:
        descriptions = description.split("/")
        for desc in descriptions:
            desc = desc.strip() 
            mapping[desc] = data 
    else:
        mapping[description] = data

# %%
mapping
# Out:
# {'age_03': 'Binned age group',
#  'age_12': 'Binned age group',
#  'urban_03': 'Locality size',
#  'urban_12': 'Locality size',
#  'married_03': 'Marital status',
#  'married_12': 'Marital status',
#  'n_mar_03': 'Number of marriages',
#  'n_mar_12': 'Number of marriages',
#  'edu_gru_03': 'Binned education level',
#  'edu_gru_12': 'Binned education level',
#  'n_living_child_03': 'Binned number of living children',
#  'n_living_child_12': 'Binned number of living children',
#  'migration_03': 'Has lived or worked in the U.S.',
#  'migration_12': 'Has lived or worked in the U.S.',
#  'glob_hlth_03': 'Self-reported global health',
#  'glob_hlth_12': 'Self-reported global health',
#  'adl_dress_03': 'Has difficulty getting dressed',
#  'adl_dress_12': 'Has difficulty getting dressed',
#  'adl_walk_03': 'Has difficulty walking from one side of the room to the other',
#  'adl_walk_12': 'Has difficulty walking from one side of the room to the other',
#  'adl_bath_03': 'Has difficulty bathing themselves in a tub or shower',
#  'adl_bath_12': 'Has difficulty bathing themselves in a tub or shower',
#  'adl_eat_03': 'Has difficulty eating',
#  'adl_eat_12': 'Has difficulty eating',
#  'adl_bed_03': 'Has difficulty getting in and out of bed',
#  'adl_bed_12': 'Has difficulty getting in and out of bed',
#  'adl_toilet_03': 'Has difficulty using the toilet',
#  'adl_toilet_12': 'Has difficulty using the toilet',
#  'n_adl_03': 'Number of activities of daily living (ADL) limitations (0-5)',
#  'n_adl_12': 'Number of activities of daily living (ADL) limitations (0-5)',
#  'iadl_money_03': 'Has difficulty managing money',
#  'iadl_money_12': 'Has difficulty managing money',
#  'iadl_meds_03': 'Has difficulty taking medications',
#  'iadl_meds_12': 'Has difficulty taking medications',
#  'iadl_shop_03': 'Has difficulty shopping for groceries',
#  'iadl_shop_12': 'Has difficulty shopping for groceries',
#  'iadl_meals_03': 'Has difficulty preparing a hot meal',
#  'iadl_meals_12': 'Has difficulty preparing a hot meal',
#  'n_iadl_03': 'Number of instrumental activities of daily living (IADL) limitations (0-4)',
#  'n_iadl_12': 'Number of instrumental activities of daily living (IADL) limitations (0-4)',
#  'depressed_03': 'Most of the past week, felt depressed',
#  'depressed_12': 'Most of the past week, felt depressed',
#  'hard_03': 'Most of the past week, felt that everything was an effort',
#  'hard_12': 'Most of the past week, felt that everything was an effort',
#  'restless_03': 'Most of the past week, felt that their sleep was restless',
#  'restless_12': 'Most of the past week, felt that their sleep was restless',
#  'happy_03': 'Most of the past week, felt happy',
#  'happy_12': 'Most of the past week, felt happy',
#  'lonely_03': 'Most of the past week, felt lonely',
#  'lonely_12': 'Most of the past week, felt lonely',
#  'enjoy_03': 'Most of the past week, felt that they enjoyed life',
#  'enjoy_12': 'Most of the past week, felt that they enjoyed life',
#  'sad_03': 'Most of the past week, felt sad',
#  'sad_12': 'Most of the past week, felt sad',
#  'tired_03': 'Most of the past week, felt tired',
#  'tired_12': 'Most of the past week, felt tired',
#  'energetic_03': 'Most of the past week, felt they had a lot of energy',
#  'energetic_12': 'Most of the past week, felt they had a lot of energy',
#  'n_depr_03': 'Number of CES-D depressive symptoms (0-9)',
#  'n_depr_12': 'Number of CES-D depressive symptoms (0-9)',
#  'cesd_depressed_03': 'Has 5+ CES-D depressive symptoms',
#  'cesd_depressed_12': 'Has 5+ CES-D depressive symptoms',
#  'hypertension_03': 'Has been diagnosed with hypertension',
#  'hypertension_12': 'Has been diagnosed with hypertension',
#  'diabetes_03': 'Has been diagnosed with diabetes',
#  'diabetes_12': 'Has been diagnosed with diabetes',
#  'resp_ill_03': 'Has been diagnosed with respiratory illness',
#  'resp_ill_12': 'Has been diagnosed with respiratory illness',
#  'arthritis_03': 'Has been diagnosed with arthritis/rheumatism',
#  'arthritis_12': 'Has been diagnosed with arthritis/rheumatism',
#  'hrt_attack_03': 'Has been told they had a heart attack',
#  'hrt_attack_12': 'Has been told they had a heart attack',
#  'stroke_03': 'Has been told they had a stroke',
#  'stroke_12': 'Has been told they had a stroke',
#  'cancer_03': 'Has been diagnosed with cancer',
#  'cancer_12': 'Has been diagnosed with cancer',
#  'n_illnesses_03': 'Number of illnesses (0-7)',
#  'n_illnesses_12': 'Number of illnesses (0-7)',
#  'bmi_03': 'Binned body mass index',
#  'bmi_12': 'Binned body mass index',
#  'exer_3xwk_03': 'Exercises 3+ times per week',
#  'exer_3xwk_12': 'Exercises 3+ times per week',
#  'alcohol_03': 'Currently drinks alcohol',
#  'alcohol_12': 'Currently drinks alcohol',
#  'tobacco_03': 'Currently smokes tobacco',
#  'tobacco_12': 'Currently smokes tobacco',
#  'test_chol_03': 'Has had a cholesterol blood test',
#  'test_chol_12': 'Has had a cholesterol blood test',
#  'test_tuber_03': 'Has been tested for tuberculosis',
#  'test_tuber_12': 'Has been tested for tuberculosis',
#  'test_diab_03': 'Has been tested for diabetes',
#  'test_diab_12': 'Has been tested for diabetes',
#  'test_pres_03': 'Has been tested for high blood pressure',
#  'test_pres_12': 'Has been tested for high blood pressure',
#  'hosp_03': 'Has been hospitalized at least one night in the last year',
#  'hosp_12': 'Has been hospitalized at least one night in the last year',
#  'visit_med_03': 'Has visited a doctor at least once in the last year',
#  'visit_med_12': 'Has visited a doctor at least once in the last year',
#  'out_proc_03': 'Has had at least one outpatient procedure in the last year',
#  'out_proc_12': 'Has had at least one outpatient procedure in the last year',
#  'visit_dental_03': 'Has visited a dentist at least once in the last year',
#  'visit_dental_12': 'Has visited a dentist at least once in the last year',
#  'imss_03': 'Has health coverage with IMSS',
#  'imss_12': 'Has health coverage with IMSS',
#  'issste_03': 'Has health coverage with ISSSTE/ISSSTE Estatal',
#  'issste_12': 'Has health coverage with ISSSTE/ISSSTE Estatal',
#  'pem_def_mar_03': 'Has health coverage with PEMEX, Defensa, or Marina',
#  'pem_def_mar_12': 'Has health coverage with PEMEX, Defensa, or Marina',
#  'insur_private_03': 'Has health coverage with private health insurance',
#  'insur_private_12': 'Has health coverage with private health insurance',
#  'insur_other_03': 'Has health coverage with other health insurance',
#  'insur_other_12': 'Has health coverage with other health insurance',
#  'seg_pop_12': 'Has health coverage with Seguro Popular',
#  'insured_03': 'Has health insurance',
#  'insured_12': 'Has health insurance',
#  'decis_famil_03': 'Weight in family decisions',
#  'decis_famil_12': 'Weight in family decisions',
#  'decis_personal_03': 'Weight over personal decisions',
#  'decis_personal_12': 'Weight over personal decisions',
#  'employment_03': 'Employment status',
#  'employment_12': 'Employment status',
#  'vax_flu_12': 'Has been vaccinated against flu',
#  'vax_pneu_12': 'Has been vaccinated against pneumonia',
#  'care_adult_12': 'Uses time to look after a sick or disabled adult',
#  'care_child_12': 'Uses time to look after children under 12',
#  'volunteer_12': 'Uses time to volunteer for a non-profit',
#  'attends_class_12': 'Uses time to attend training course, lecture, or class',
#  'attends_club_12': 'Uses time to attend sports or social club',
#  'reads_12': 'Uses time to read books, magazines, newspapers',
#  'games_12': 'Uses time to do crosswords, jigsaw puzzles, number games',
#  'table_games_12': 'Uses time to play tabletop games. E.g., cards, dominoes, chess',
#  'comms_tel_comp_12': 'Uses time to talk on the phone or send message/use the web on a computer',
#  'act_mant_12': 'Uses time to maintain a house, do repairs, garden, etc.',
#  'tv_12': 'Uses time to watch television',
#  'sewing_12': 'Uses time to sew, emboider, knit, make crafts',
#  'satis_ideal_12': 'How much they agree with the statement that their life is close to ideal',
#  'satis_excel_12': 'How much they agree with the statement that life is excellent',
#  'satis_fine_12': 'How much they agree with the statement that they are satisfied with their life',
#  'cosas_imp_12': 'How much they agree with the statement that they have achieved the things in life that are important to them',
#  'wouldnt_change_12': 'How much they agree with the statement that they would change almost nothing about their life',
#  'memory_12': 'Self-reported memory',
#  'ragender': 'Gender',
#  'rameduc_m': "Mother's education level",
#  'rafeduc_m': "Father's education level",
#  'sgender_03': "Spouse's gender",
#  'sgender_12': "Spouse's gender",
#  'rjob_hrswk_03': 'Hours per week that they worked at their main job',
#  'rjob_hrswk_12': 'Hours per week that they worked at their main job',
#  'rjlocc_m_03': 'Category of their longest occuptation',
#  'rjlocc_m_12': 'Category of their longest occuptation',
#  'rjob_end_03': 'Year that their last job ended',
#  'rjob_end_12': 'Year that their last job ended',
#  'rjobend_reason_03': 'Reason that their last job ended',
#  'rjobend_reason_12': 'Reason that their last job ended',
#  'rearnings_03': 'Earnings from employment',
#  'rearnings_12': 'Earnings from employment',
#  'searnings_03': "Spouse's earnings from employment",
#  'searnings_12': "Spouse's earnings from employment",
#  'hincome_03': 'Household income',
#  'hincome_12': 'Household income',
#  'hinc_business_03': 'Household income from business',
#  'hinc_business_12': 'Household income from business',
#  'hinc_rent_03': 'Household income from rent',
#  'hinc_rent_12': 'Household income from rent',
#  'hinc_assets_03': 'Household income from financial assets',
#  'hinc_assets_12': 'Household income from financial assets',
#  'hinc_cap_03': 'Household capital income',
#  'hinc_cap_12': 'Household capital income',
#  'rinc_pension_03': 'Income from pensions',
#  'rinc_pension_12': 'Income from pensions',
#  'sinc_pension_03': "Spouse's income from pensions",
#  'sinc_pension_12': "Spouse's income from pensions",
#  'rrelgimp_03': 'Importance of religion',
#  'rrelgimp_12': 'Importance of religion',
#  'rrfcntx_m_12': 'How often they see friends and relatives',
#  'rsocact_m_12': 'How often they have social activities',
#  'rrelgwk_12': 'Participates in weekly religious services',
#  'a16a_12': 'Year when respondent first left for the U.S., if they ever lived in the U.S.',
#  'a21_12': 'Total years lived or worked in the U.S.',
#  'a22_12': 'Main job type during longest stay in the U.S.',
#  'a33b_12': 'U.S. residency status',
#  'a34_12': 'Speaks English',
#  'j11_12': 'Floor material of residence'}

# %%
for idx in range(len(testing_df)):
    sentences = []
    for column in testing_df.columns:
        if testing_df[column].dtype == "object":
            description = mapping[column]
            info = testing_df.loc[idx,column]
            sentences.append("{} is {}.".format(description, info))
    break

# %%
sentences
# Out:
# ['Binned age group is nan.',
#  'Locality size is nan.',
#  'Marital status is nan.',
#  'Binned education level is nan.',
#  'Binned number of living children is nan.',
#  'Self-reported global health is nan.',
#  'Binned body mass index is nan.',
#  'Weight in family decisions is nan.',
#  'Employment status is nan.',
#  'Binned age group is 2. 60–69.',
#  'Locality size is 0. <100,000.',
#  'Marital status is 1. Married or in civil union.',
#  'Binned education level is 0. No education.',
#  'Binned number of living children is 1. 1 or 2.',
#  'Self-reported global health is 4. Fair.',
#  'Binned body mass index is 3. Overweight.',
#  'Weight in family decisions is 2. Approximately equal weight.',
#  'Weight over personal decisions is 1. A lot.',
#  'Employment status is 1. Currently Working.',
#  'How much they agree with the statement that their life is close to ideal is 3. Disagrees.',
#  'How much they agree with the statement that life is excellent is 3. Disagrees.',
#  'How much they agree with the statement that they are satisfied with their life is 1. Agrees.',
#  'How much they agree with the statement that they have achieved the things in life that are important to them is 1. Agrees.',
#  'How much they agree with the statement that they would change almost nothing about their life is 3. Disagrees.',
#  'Self-reported memory is 2. Very good.',
#  'Gender is 1.Man.',
#  "Mother's education level is 1.None.",
#  "Father's education level is 1.None.",
#  "Spouse's gender is nan.",
#  'Category of their longest occuptation is nan.',
#  'Reason that their last job ended is nan.',
#  'Importance of religion is nan.',
#  "Spouse's gender is 2.Woman.",
#  'Category of their longest occuptation is 6.Workers in Agriculture, Livestock, Forestry, and Fishing.',
#  'Reason that their last job ended is nan.',
#  'Importance of religion is 2.somewhat important.',
#  'How often they see friends and relatives is 9.Never.',
#  'How often they have social activities is 9.Never.',
#  'Participates in weekly religious services is 0.No.',
#  'Main job type during longest stay in the U.S. is nan.',
#  'U.S. residency status is nan.',
#  'Speaks English is nan.',
#  'Floor material of residence is Concrete 2.']

# %%
def processing(data):
    if pd.isna(data):
        return "Not Available"
    else:
        data_str = str(data)
        if "." in data_str:
            return str(data_str.split(".")[1])
        else:
            return str(''.join([i for i in data_str if not i.isdigit()]))

# %%
for idx in range(len(testing_df)):
    sentences = []
    for column in testing_df.columns:
        if testing_df[column].dtype == "object":
            description = mapping[column]
            info = testing_df.loc[idx,column]
            processed_info = processing(info)
            sentences.append("{} is {}.".format(description, processed_info))
    break

# %%
sentences
# Out:
# ['Binned age group is Not Available.',
#  'Locality size is Not Available.',
#  'Marital status is Not Available.',
#  'Binned education level is Not Available.',
#  'Binned number of living children is Not Available.',
#  'Self-reported global health is Not Available.',
#  'Binned body mass index is Not Available.',
#  'Weight in family decisions is Not Available.',
#  'Employment status is Not Available.',
#  'Binned age group is  60–69.',
#  'Locality size is  <100,000.',
#  'Marital status is  Married or in civil union.',
#  'Binned education level is  No education.',
#  'Binned number of living children is  1 or 2.',
#  'Self-reported global health is  Fair.',
#  'Binned body mass index is  Overweight.',
#  'Weight in family decisions is  Approximately equal weight.',
#  'Weight over personal decisions is  A lot.',
#  'Employment status is  Currently Working.',
#  'How much they agree with the statement that their life is close to ideal is  Disagrees.',
#  'How much they agree with the statement that life is excellent is  Disagrees.',
#  'How much they agree with the statement that they are satisfied with their life is  Agrees.',
#  'How much they agree with the statement that they have achieved the things in life that are important to them is  Agrees.',
#  'How much they agree with the statement that they would change almost nothing about their life is  Disagrees.',
#  'Self-reported memory is  Very good.',
#  'Gender is Man.',
#  "Mother's education level is None.",
#  "Father's education level is None.",
#  "Spouse's gender is Not Available.",
#  'Category of their longest occuptation is Not Available.',
#  'Reason that their last job ended is Not Available.',
#  'Importance of religion is Not Available.',
#  "Spouse's gender is Woman.",
#  'Category of their longest occuptation is Workers in Agriculture, Livestock, Forestry, and Fishing.',
#  'Reason that their last job ended is Not Available.',
#  'Importance of religion is somewhat important.',
#  'How often they see friends and relatives is Never.',
#  'How often they have social activities is Never.',
#  'Participates in weekly religious services is No.',
#  'Main job type during longest stay in the U.S. is Not Available.',
#  'U.S. residency status is Not Available.',
#  'Speaks English is Not Available.',
#  'Floor material of residence is Concrete .']
